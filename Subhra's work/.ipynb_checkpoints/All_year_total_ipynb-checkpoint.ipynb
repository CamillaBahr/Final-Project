# %%
import pandas as pd
import numpy as np

# %%
SN_2015_Total_to_load = "../Final Project.Sarah/Final_Total_Losses.csv"

# Read data File and store into Pandas Data Frames
Total_2015_df= pd.read_csv(SN_2015_Total_to_load)
# Drop column 0(Unnammed)
Total_2015= Total_2015_df.drop(Total_2015_df.columns[[0]], axis=1) 

Total_2015.head()
# Out:
#         State  Winter_2015  Spring_2015  Summer_2015  Fall_2015  Total_2015  \
# 0     Alabama         1800          860         1400        610        4670
# 1     Arizona         4600         5500         6000      12000       28100
# 2    Arkansas         1500         1900         9000       2400       14800
# 3  California       255000       104000        76000     149000      584000
# 4    Colorado         1500         1900         4500       2500       10400
#
#    Winter_2016  Spring_2016  Summer_2016  Fall_2016  Total_2016  Winter_2017  \
# 0         1700          930         1200        610        4440         1600
# 1         4700         3700         6000       6500       20900         6000
# 2         5000         3400         1500       2500       12400         3500
# 3       200000       108000        82000     205000      595000       195000
# 4          750         1800         6500       4500       13550         1100
#
# ...
