# %%
import pandas as pd
import numpy as np

# %%
SN_Total_to_load = "../Final Project.Sarah/Final_Total_Losses.csv"

# Read data File and store into Pandas Data Frames
Total_2015_df= pd.read_csv(SN_Total_to_load)
# Drop column 0(Unnammed)
Total_dropcol= Total_2015_df.drop(Total_2015_df.columns[[0]], axis=1) 
Total_=Total_2015_dropcol.rename(columns={'2018_total': 'Total_2018'})

Total_2015
# Out:
#              State  Winter_2015  Spring_2015  Summer_2015  Fall_2015  \
# 0          Alabama         1800          860         1400        610
# 1          Arizona         4600         5500         6000      12000
# 2         Arkansas         1500         1900         9000       2400
# 3       California       255000       104000        76000     149000
# 4         Colorado         1500         1900         4500       2500
# 5      Connecticut          870           80           50        210
# 6          Florida        42000        35000        36000      37000
# 7          Georgia        14500        23000        13000      18000
# 8           Hawaii          380          120         2700        690
# 9            Idaho         3700         6500        14000      22000
# 10        Illinois         4200         1300         1400        690
# 11         Indiana         2100         1300         1600       1100
# 12            Iowa         3100         1400         3000       4300
# ...
