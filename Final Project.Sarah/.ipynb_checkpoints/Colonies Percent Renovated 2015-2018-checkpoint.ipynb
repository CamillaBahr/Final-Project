# %%
import pandas as pd
import numpy as np

# %%
colonyren_2015_to_load = "Final_Colony_2015.csv"

# Read data File and store into Pandas Data Frames
colonyren_df_2015= pd.read_csv(colonyren_2015_to_load)
colonyren_df_2015.head()
# Out:
#    Unnamed: 0       State  Winter_2015\r\nNo_of_colonies  Winter_2015\r\nLost  \
# 0           0     Alabama                           7000                 1800
# 1           1     Arizona                          35000                 4600
# 2           2    Arkansas                          13000                 1500
# 3           3  California                        1440000               255000
# 4           4    Colorado                           3500                 1500
#
#    Winter_2015\r\nPer_lost  Winter_2015\r\nAdded  Winter_2015\r\nRenovated  \
# 0                       26                  2800                       250
# 1                       13                  3400                      2100
# 2                       11                  1200                        90
# 3                       15                250000                    124000
# 4                       12                   200                       140
#
# ...

# %%
list(colonyren_df_2015)
# Out:
# ['Unnamed: 0',
#  'State',
#  'Winter_2015\r\nNo_of_colonies',
#  'Winter_2015\r\nLost',
#  'Winter_2015\r\nPer_lost',
#  'Winter_2015\r\nAdded',
#  'Winter_2015\r\nRenovated',
#  'Winter_2015\r\nPer_renovated',
#  'Spring_2015\r\nNo_of_colonies',
#  'Spring_2015\r\nLost',
#  'Spring_2015\r\nPer_lost',
#  'Spring_2015\r\nAdded',
#  'Spring_2015\r\nRenovated',
#  'Spring_2015\r\nPer_renovated',
#  'Summer_2015\r\nNo_of_colonies',
#  'Summer_2015\r\nLost',
#  'Summer_2015\r\nPer_lost',
#  'Summer_2015\r\nAdded',
#  'Summer_2015\r\nRenovated',
#  'Summer_2015\r\nPer_renovated',
#  'Fall_2015\r\nNo_of_colonies',
#  'Fall_2015\r\nLost',
#  'Fall_2015\r\nPer_lost',
#  'Fall_2015\r\nAdded',
#  'Fall_2015\r\nRenovated',
#  'Fall_2015\r\nPer_renovated']

# %%
#select "percent renovated" columns from 2015 df
#df1 = df[['a','d']]

Colony_perrencolumns_2015 = colonyren_df_2015[['State', 'Winter_2015\r\nPer_renovated','Spring_2015\r\nPer_renovated',
                                           'Summer_2015\r\nPer_renovated', 'Fall_2015\r\nPer_renovated']]
Colony_perrencolumns_2015.head()
# Out:
#         State  Winter_2015\r\nPer_renovated  Spring_2015\r\nPer_renovated  \
# 0     Alabama                             4                             9
# 1     Arizona                             6                            21
# 2    Arkansas                             1                            41
# 3  California                             7                            27
# 4    Colorado                             1                            14
#
#    Summer_2015\r\nPer_renovated  Fall_2015\r\nPer_renovated
# 0                             3                           1
# 1                            39                          41
# 2                             1                           0
# 3                            12                           6
# 4                             5                           0

# %%
#####
##CAMILLA'S DATA
#####
colonyren_2016_to_load = "Final_Colony_2016.csv"

# Read data File and store into Pandas Data Frames
colonyren_df_2016= pd.read_csv(colonyren_2016_to_load)
colonyren_df_2016.head()
# Out:
#    Unnamed: 0       State  Winter_2016\nNo_of_colonies  Winter_2016\nLost  \
# 0           0     Alabama                         7500               1700
# 1           1     Arizona                        30000               4700
# 2           2    Arkansas                        27000               5000
# 3           3  California                      1130000             200000
# 4           4    Colorado                         5000                750
#
#    Winter_2016\nPer_lost  Winter_2016\nAdded  Winter_2016\nRenovated  \
# 0                     23                2100                      90
# 1                     16                3500                     150
# 2                     19                5000                    1100
# 3                     14              210000                  139000
# 4                      9                1700                      10
#
#    Winter_2016\nPer_renovated  Spring_2016\nNo_of_colonies  Spring_2016\nlost  \
# ...

# %%
list(colonyren_df_2016)
# Out:
# ['Unnamed: 0',
#  'State',
#  'Winter_2016\nNo_of_colonies',
#  'Winter_2016\nLost',
#  'Winter_2016\nPer_lost',
#  'Winter_2016\nAdded',
#  'Winter_2016\nRenovated',
#  'Winter_2016\nPer_renovated',
#  'Spring_2016\nNo_of_colonies',
#  'Spring_2016\nlost',
#  'Spring_2016\nPer_lost',
#  'Spring_2016\nAdded',
#  'Spring_2016\nRenovated',
#  'Spring_2016\nPer_renovated',
#  'Summer_2016\nNo_of_colonies',
#  'Summer_2016\nLost',
#  'Summer_2016\nPer_lost',
#  'Summer_2016\nAdded',
#  'Summer_2016\nRenovated',
#  'Summer_2016\nPer_renovated',
#  'Fall_2016\nNo_of_colonies',
#  'Fall_2016\nLost',
#  'Fall_2016\nPer_lost',
#  'Fall_2016\nAdded',
#  'Fall_2016\nRenovated',
#  'Fall_2016\nPer_renovated']

# %%
#select "percent renovated" columns from 2016 df
#df1 = df[['a','d']]

Colony_perrencolumns_2016 = colonyren_df_2016[['State', 'Winter_2016\nPer_renovated','Spring_2016\nPer_renovated',
                                           'Summer_2016\nPer_renovated', 'Fall_2016\nPer_renovated']]
Colony_perrencolumns_2016.head()
# Out:
#         State  Winter_2016\nPer_renovated Spring_2016\nPer_renovated  \
# 0     Alabama                           1                          9
# 1     Arizona                           1                          7
# 2    Arkansas                           4                          7
# 3  California                          10                         16
# 4    Colorado                           0                          2
#
#   Summer_2016\nPer_renovated  Fall_2016\nPer_renovated
# 0                          1                         0
# 1                          8                        10
# 2                        (Z)                         0
# 3                         10                         3
# 4                          2                         0

# %%
colonyren_2017_to_load = "Final_Colony_2017.csv"

# Read data File and store into Pandas Data Frames
colonyren_df_2017= pd.read_csv(colonyren_2017_to_load)
colonyren_df_2017.head()
# Out:
#         State  Winter_2017\nNo_of_colonies  Winter_2017\nLost  \
# 0     Alabama                         7000               1600
# 1     Arizona                        31000               6000
# 2    Arkansas                        18000               3500
# 3  California                      1170000             195000
# 4    Colorado                         9500               1100
#
#    Winter_2017\nPer_lost  Winter_2017\nAdded  Winter_2017\nRenovated  \
# 0                     23                 570                     740
# 1                     19                2900                       0
# 2                     18                 430                     230
# 3                     13              137000                   93000
# 4                      5                 100                       0
#
#    Winter_2017\nPer_renovated  Spring_2017\nNo_of_colonies  Spring_2017\nLost  \
# 0                          11                         6500                440
# ...

# %%
list(colonyren_df_2017)
# Out:
# ['State',
#  'Winter_2017\nNo_of_colonies',
#  'Winter_2017\nLost',
#  'Winter_2017\nPer_lost',
#  'Winter_2017\nAdded',
#  'Winter_2017\nRenovated',
#  'Winter_2017\nPer_renovated',
#  'Spring_2017\nNo_of_colonies',
#  'Spring_2017\nLost',
#  'Spring_2017\nPer_lost',
#  'Spring_2017\nAdded',
#  'Spring_2017\nRenovated',
#  'Spring_2017\nPer_renovated',
#  'Summer_2017\nNo_of_colonies',
#  'Summer_2017\nLost',
#  'Summer_2017\nPer_lost',
#  'Summer_2017\nAdded',
#  'Summer_2017\nRenovated',
#  'Summer_2017\nPer_renovated',
#  'Fall_2017\nNo_of_colonies',
#  'Fall_2017\nLost',
#  'Fall_2017\nPer_lost',
#  'Fall_2017\nAdded',
#  'Fall_2017\nRenovated',
#  'Fall_2017\nPer_renovated']

# %%
#select "percent renovated" columns from 2017 df
#df1 = df[['a','d']]

Colony_perrencolumns_2017 = colonyren_df_2017[['State', 'Winter_2017\nPer_renovated','Spring_2017\nPer_renovated',
                                           'Summer_2017\nPer_renovated', 'Fall_2017\nPer_renovated']]
Colony_perrencolumns_2017.head()
# Out:
#         State  Winter_2017\nPer_renovated  Spring_2017\nPer_renovated  \
# 0     Alabama                          11                           8
# 1     Arizona                           0                          14
# 2    Arkansas                           1                           5
# 3  California                           6                          22
# 4    Colorado                           0                          24
#
#   Summer_2017\nPer_renovated  Fall_2017\nPer_renovated
# 0                          6                         7
# 1                         12                         4
# 2                          1                         2
# 3                         11                         9
# 4                         15                        12

# %%
colonyren_2018_to_load = "Final_Colony_2018.csv"

# Read data File and store into Pandas Data Frames
colonyren_df_2018= pd.read_csv(colonyren_2018_to_load)
colonyren_df_2018.head()
# Out:
#         State  Winter_2018\nNo_of_colonies  Winter_2018\nLost  \
# 0     Alabama                         7500                820
# 1     Arizona                        25000               6000
# 2    Arkansas                        22000               7500
# 3  California                      1150000             220000
# 4    Colorado                        13000               4900
#
#    Winter_2018\nPer_lost  Winter_2018\nAdded  Winter_2018\nRenovated  \
# 0                     11                1200                    1500
# 1                     23                 810                     230
# 2                     34                 540                     810
# 3                     14              200000                  132500
# 4                     23                1400                     190
#
#    Winter_2018\nPer_renovated  Spring_2018\nNo_of_colonies  Spring_2018\nLost  \
# 0                          20                         7500                810
# ...

# %%
list(colonyren_df_2018)
# Out:
# ['State',
#  'Winter_2018\nNo_of_colonies',
#  'Winter_2018\nLost',
#  'Winter_2018\nPer_lost',
#  'Winter_2018\nAdded',
#  'Winter_2018\nRenovated',
#  'Winter_2018\nPer_renovated',
#  'Spring_2018\nNo_of_colonies',
#  'Spring_2018\nLost',
#  'Spring_2018\nPer_lost',
#  'Spring_2018\nAdded',
#  'Spring_2018\nRenovated',
#  'Spring_2018\nPer_renovated']

# %%
#select "percent lost" columns from 2018 df
#df1 = df[['a','d']]

Colony_perrencolumns_2018 = colonyren_df_2018[['State', 'Winter_2018\nPer_renovated','Spring_2018\nPer_renovated']]
Colony_perrencolumns_2018.head()
# Out:
#         State  Winter_2018\nPer_renovated  Spring_2018\nPer_renovated
# 0     Alabama                          20                           8
# 1     Arizona                           1                          11
# 2    Arkansas                           4                          17
# 3  California                           9                          21
# 4    Colorado                           1                          18

# %%
Final_Colony_Percent_Renovated = Colony_perrencolumns_2015.merge(Colony_perrencolumns_2016, on="State").merge(Colony_perrencolumns_2017, on="State").merge(Colony_perrencolumns_2018, on="State")
Final_Colony_Percent_Renovated.head()
# Out:
#         State  Winter_2015\r\nPer_renovated  Spring_2015\r\nPer_renovated  \
# 0     Alabama                             4                             9
# 1     Arizona                             6                            21
# 2    Arkansas                             1                            41
# 3  California                             7                            27
# 4    Colorado                             1                            14
#
#    Summer_2015\r\nPer_renovated  Fall_2015\r\nPer_renovated  \
# 0                             3                           1
# 1                            39                          41
# 2                             1                           0
# 3                            12                           6
# 4                             5                           0
#
#    Winter_2016\nPer_renovated Spring_2016\nPer_renovated  \
# 0                           1                          9
# ...

# %%
#Export Final_Colony_Percent_Renovated to csv
Final_Colony_Percent_Renovated.to_csv("Final_Colony_Percent_Renovated.csv")
