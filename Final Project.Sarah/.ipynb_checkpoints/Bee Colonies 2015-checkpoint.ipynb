# %%
import pandas as pd
import numpy as np

# %%
Bee2015_Jan_March_to_load = "Jan-Mar2015.csv"

# Read data File and store into Pandas Data Frames
Jan_March2015= pd.read_csv(Bee2015_Jan_March_to_load)
Jan_March2015.head()
# Out:
#    5  h       State  Number of colonies Maximum colonies   Lost colonies  \
# 0  5  d     Alabama                7000              7000           1800
# 1  5  d     Arizona               35000             35000           4600
# 2  5  d    Arkansas               13000             14000           1500
# 3  5  d  California             1440000           1690000         255000
# 4  5  d    Colorado                3500             12500           1500
#
#    Percent lost   Added colonies Renovated colonies  Percent renovated
# 0             26            2800                 250                  4
# 1             13            3400                2100                  6
# 2             11            1200                  90                  1
# 3             15          250000              124000                  7
# 4             12             200                 140                  1

# %%
Jan_March2015_df = Jan_March2015.drop(Jan_March2015.columns[[0, 1, 4]], axis=1) 

Jan_March2015_df.head()
# Out:
#         State  Number of colonies  Lost colonies  Percent lost   \
# 0     Alabama                7000           1800             26
# 1     Arizona               35000           4600             13
# 2    Arkansas               13000           1500             11
# 3  California             1440000         255000             15
# 4    Colorado                3500           1500             12
#
#    Added colonies Renovated colonies  Percent renovated
# 0            2800                 250                  4
# 1            3400                2100                  6
# 2            1200                  90                  1
# 3          250000              124000                  7
# 4             200                 140                  1

# %%
list(Jan_March2015_df)
# Out:
# ['State',
#  'Number of colonies',
#  'Lost colonies',
#  'Percent lost ',
#  'Added colonies',
#  'Renovated colonies ',
#  'Percent renovated ']

# %%
Jan_Mar2015_Final= Jan_March2015_df.rename(columns={'State':'State',
                                                      'Number of colonies': 'Winter_2015\nNo_of_colonies', 
                                                      #'Maximum colonies ': 'Winter_2015\nMax',
                                                     'Lost colonies': 'Winter_2015\nLost', 
                                                      'Percent lost ': 'Winter_2015\nPer_lost',
                                                         'Added colonies': 'Winter_2015\nAdded',
                                                      'Renovated colonies ': 'Winter_2015\nRenovated', 
                                                     'Percent renovated ': 'Winter_2015\nPer_renovated'})

Jan_Mar2015_Final.head()
# Out:
#         State  Winter_2015\nNo_of_colonies  Winter_2015\nLost  \
# 0     Alabama                         7000               1800
# 1     Arizona                        35000               4600
# 2    Arkansas                        13000               1500
# 3  California                      1440000             255000
# 4    Colorado                         3500               1500
#
#    Winter_2015\nPer_lost  Winter_2015\nAdded Winter_2015\nRenovated  \
# 0                     26                2800                    250
# 1                     13                3400                   2100
# 2                     11                1200                     90
# 3                     15              250000                 124000
# 4                     12                 200                    140
#
#   Winter_2015\nPer_renovated
# 0                          4
# 1                          6
# 2                          1
# 3                          7
# 4                          1

# %%
Jan_Mar2015_Final.replace('-',np.NaN,inplace = True)
Jan_Mar2015_Final.replace('(Z)',np.NaN,inplace = True)

Jan_Mar2015_Final.fillna(0,inplace = True)

Jan_Mar2015_Final.head()
# Out:
#         State  Winter_2015\nNo_of_colonies  Winter_2015\nLost  \
# 0     Alabama                         7000               1800
# 1     Arizona                        35000               4600
# 2    Arkansas                        13000               1500
# 3  California                      1440000             255000
# 4    Colorado                         3500               1500
#
#    Winter_2015\nPer_lost  Winter_2015\nAdded Winter_2015\nRenovated  \
# 0                     26                2800                    250
# 1                     13                3400                   2100
# 2                     11                1200                     90
# 3                     15              250000                 124000
# 4                     12                 200                    140
#
#   Winter_2015\nPer_renovated
# 0                          4
# 1                          6
# 2                          1
# 3                          7
# 4                          1

# %%
Bee2015_Apr_Jun_to_load = "Apr-Jun2015.csv"

# Read data File and store into Pandas Data Frames
Apr_Jun2015= pd.read_csv(Bee2015_Apr_Jun_to_load)
Apr_Jun2015.head()
# Out:
#    5  h       State  Number of colonies Maximum colonies   Lost colonies  \
# 0  1  d     Alabama                7500              7500            860
# 1  1  d     Arizona               33000             33000           5500
# 2  1  d    Arkansas               13500             13500           1900
# 3  1  d  California             1040000           1050000         104000
# 4  1  d    Colorado               12000             25000           1900
#
#    Percent lost   Added colonies  Renovated colonies   Percent renovated
# 0             12            1900                  680                   9
# 1             17           19500                 7000                  21
# 2             14           11500                 5500                  41
# 3             10          170000               285000                  27
# 4              8            6000                 3500                  14

# %%
Apr_Jun2015_df = Apr_Jun2015.drop(Apr_Jun2015.columns[[0, 1, 4]], axis=1) 

Apr_Jun2015_df.head()
# Out:
#         State  Number of colonies  Lost colonies  Percent lost   \
# 0     Alabama                7500            860             12
# 1     Arizona               33000           5500             17
# 2    Arkansas               13500           1900             14
# 3  California             1040000         104000             10
# 4    Colorado               12000           1900              8
#
#    Added colonies  Renovated colonies   Percent renovated
# 0            1900                  680                   9
# 1           19500                 7000                  21
# 2           11500                 5500                  41
# 3          170000               285000                  27
# 4            6000                 3500                  14

# %%
list(Apr_Jun2015_df)
# Out:
# ['State',
#  'Number of colonies',
#  'Lost colonies',
#  'Percent lost ',
#  'Added colonies',
#  'Renovated colonies ',
#  'Percent renovated ']

# %%
Apr_Jun2015_Final= Apr_Jun2015_df.rename(columns={'State':'State',
                                                      'Number of colonies': 'Spring_2015\nNo_of_colonies', 
                                                      #'Maximum colonies ': 'Spring_2015\nMax',
                                                     'Lost colonies': 'Spring_2015\nLost', 
                                                      'Percent lost ': 'Spring_2015\nPer_lost',
                                                         'Added colonies': 'Spring_2015\nAdded',
                                                      'Renovated colonies ': 'Spring_2015\nRenovated', 
                                                     'Percent renovated ': 'Spring_2015\nPer_renovated'})

Apr_Jun2015_Final.head()
# Out:
#         State  Spring_2015\nNo_of_colonies  Spring_2015\nLost  \
# 0     Alabama                         7500                860
# 1     Arizona                        33000               5500
# 2    Arkansas                        13500               1900
# 3  California                      1040000             104000
# 4    Colorado                        12000               1900
#
#    Spring_2015\nPer_lost  Spring_2015\nAdded  Spring_2015\nRenovated  \
# 0                     12                1900                     680
# 1                     17               19500                    7000
# 2                     14               11500                    5500
# 3                     10              170000                  285000
# 4                      8                6000                    3500
#
#    Spring_2015\nPer_renovated
# 0                           9
# 1                          21
# 2                          41
# 3                          27
# ...

# %%
Apr_Jun2015_Final.replace('-',np.NaN,inplace = True)
Apr_Jun2015_Final.replace('(Z)',np.NaN,inplace = True)

Apr_Jun2015_Final.fillna(0,inplace = True)

Apr_Jun2015_Final.head()
# Out:
#         State  Spring_2015\nNo_of_colonies  Spring_2015\nLost  \
# 0     Alabama                         7500                860
# 1     Arizona                        33000               5500
# 2    Arkansas                        13500               1900
# 3  California                      1040000             104000
# 4    Colorado                        12000               1900
#
#    Spring_2015\nPer_lost  Spring_2015\nAdded  Spring_2015\nRenovated  \
# 0                     12                1900                     680
# 1                     17               19500                    7000
# 2                     14               11500                    5500
# 3                     10              170000                  285000
# 4                      8                6000                    3500
#
#    Spring_2015\nPer_renovated
# 0                           9
# 1                          21
# 2                          41
# 3                          27
# ...

# %%
Bee2015_Jul_Sep_to_load = "Jul-Sep2015.csv"

# Read data File and store into Pandas Data Frames
Jul_Sep2015= pd.read_csv(Bee2015_Jul_Sep_to_load)
Jul_Sep2015.head()
# Out:
#    5  h       State  Number of colonies Maximum colonies   Lost colonies  \
# 0  7  d     Alabama                8500              9000           1400
# 1  7  d     Arizona               40000             40000           6000
# 2  7  d    Arkansas               23000             30000           9000
# 3  7  d  California              730000            800000          76000
# 4  7  d    Colorado               29000             30000           4500
#
#    Percent lost   Added colonies  Renovated colonies  Percent renovated
# 0             16             160                  260                  3
# 1             15            4300                15500                 39
# 2             30             500                  210                  1
# 3             10           40000                93000                 12
# 4             15            1400                 1400                  5

# %%
Jul_Sep2015_df = Jul_Sep2015.drop(Jul_Sep2015.columns[[0, 1, 4]], axis=1) 

Jul_Sep2015_df.head()
# Out:
#         State  Number of colonies  Lost colonies  Percent lost   \
# 0     Alabama                8500           1400             16
# 1     Arizona               40000           6000             15
# 2    Arkansas               23000           9000             30
# 3  California              730000          76000             10
# 4    Colorado               29000           4500             15
#
#    Added colonies  Renovated colonies  Percent renovated
# 0             160                  260                  3
# 1            4300                15500                 39
# 2             500                  210                  1
# 3           40000                93000                 12
# 4            1400                 1400                  5

# %%
list(Jul_Sep2015_df)
# Out:
# ['State',
#  'Number of colonies',
#  'Lost colonies',
#  'Percent lost ',
#  'Added colonies',
#  'Renovated colonies ',
#  'Percent renovated ']

# %%
Jul_Sep2015_Final= Jul_Sep2015_df.rename(columns={'State':'State',
                                                      'Number of colonies': 'Summer_2015\nNo_of_colonies', 
                                                      #'Maximum colonies ': 'Summer_2015\nMax',
                                                     'Lost colonies': 'Summer_2015\nLost', 
                                                      'Percent lost ': 'Summer_2015\nPer_lost',
                                                         'Added colonies': 'Summer_2015\nAdded',
                                                      'Renovated colonies ': 'Summer_2015\nRenovated', 
                                                     'Percent renovated ': 'Summer_2015\nPer_renovated'})

Jul_Sep2015_Final.head()
# Out:
#         State  Summer_2015\nNo_of_colonies  Summer_2015\nLost  \
# 0     Alabama                         8500               1400
# 1     Arizona                        40000               6000
# 2    Arkansas                        23000               9000
# 3  California                       730000              76000
# 4    Colorado                        29000               4500
#
#    Summer_2015\nPer_lost  Summer_2015\nAdded  Summer_2015\nRenovated  \
# 0                     16                 160                     260
# 1                     15                4300                   15500
# 2                     30                 500                     210
# 3                     10               40000                   93000
# 4                     15                1400                    1400
#
#   Summer_2015\nPer_renovated
# 0                          3
# 1                         39
# 2                          1
# 3                         12
# ...

# %%
Jul_Sep2015_Final.replace('-',np.NaN,inplace = True)
Jul_Sep2015_Final.replace('(Z)',np.NaN,inplace = True)

Jul_Sep2015_Final.fillna(0,inplace = True)

Jul_Sep2015_Final.head()
# Out:
#         State  Summer_2015\nNo_of_colonies  Summer_2015\nLost  \
# 0     Alabama                         8500               1400
# 1     Arizona                        40000               6000
# 2    Arkansas                        23000               9000
# 3  California                       730000              76000
# 4    Colorado                        29000               4500
#
#    Summer_2015\nPer_lost  Summer_2015\nAdded  Summer_2015\nRenovated  \
# 0                     16                 160                     260
# 1                     15                4300                   15500
# 2                     30                 500                     210
# 3                     10               40000                   93000
# 4                     15                1400                    1400
#
#   Summer_2015\nPer_renovated
# 0                          3
# 1                         39
# 2                          1
# 3                         12
# ...

# %%
Bee2015_Oct_Dec_to_load = "Oct-Dec2015.csv"

# Read data File and store into Pandas Data Frames
Oct_Dec2015= pd.read_csv(Bee2015_Oct_Dec_to_load)
Oct_Dec2015.head()
# Out:
#    5  h       State  Number of colonies Maximum colonies   Lost colonies  \
# 0  8  d     Alabama                8000              8000            610
# 1  8  d     Arizona               36000             39000          12000
# 2  8  d    Arkansas               23000             27000           2400
# 3  8  d  California              750000           1260000         149000
# 4  8  d    Colorado               24000             24000           2500
#
#    Percent lost  Added colonies Renovated colonies  Percent renovated
# 0              8             80                  60                  1
# 1             31           3000               16000                 41
# 2              9           1900                   -                  -
# 3             12          39000               75000                  6
# 4             10           3400                   -                  -

# %%
Oct_Dec2015_df = Oct_Dec2015.drop(Jul_Sep2015.columns[[0, 1, 4]], axis=1) 

Oct_Dec2015_df.head()
# Out:
#         State  Number of colonies  Lost colonies  Percent lost   \
# 0     Alabama                8000            610              8
# 1     Arizona               36000          12000             31
# 2    Arkansas               23000           2400              9
# 3  California              750000         149000             12
# 4    Colorado               24000           2500             10
#
#   Added colonies Renovated colonies  Percent renovated
# 0             80                  60                  1
# 1           3000               16000                 41
# 2           1900                   -                  -
# 3          39000               75000                  6
# 4           3400                   -                  -

# %%
list(Oct_Dec2015_df)
# Out:
# ['State',
#  'Number of colonies',
#  'Lost colonies',
#  'Percent lost ',
#  'Added colonies',
#  'Renovated colonies ',
#  'Percent renovated ']

# %%
Oct_Dec2015_Final= Oct_Dec2015_df.rename(columns={'State':'State',
                                                      'Number of colonies': 'Fall_2015\nNo_of_colonies', 
                                                      #'Maximum colonies ': 'Fall_2015\nMax',
                                                     'Lost colonies': 'Fall_2015\nLost', 
                                                      'Percent lost ': 'Fall_2015\nPer_lost',
                                                         'Added colonies': 'Fall_2015\nAdded',
                                                      'Renovated colonies ': 'Fall_2015\nRenovated', 
                                                     'Percent renovated ': 'Fall_2015\nPer_renovated'})

Oct_Dec2015_Final.head()
# Out:
#         State  Fall_2015\nNo_of_colonies  Fall_2015\nLost  \
# 0     Alabama                       8000              610
# 1     Arizona                      36000            12000
# 2    Arkansas                      23000             2400
# 3  California                     750000           149000
# 4    Colorado                      24000             2500
#
#    Fall_2015\nPer_lost Fall_2015\nAdded Fall_2015\nRenovated  \
# 0                    8               80                   60
# 1                   31             3000                16000
# 2                    9             1900                    -
# 3                   12            39000                75000
# 4                   10             3400                    -
#
#   Fall_2015\nPer_renovated
# 0                        1
# 1                       41
# 2                        -
# 3                        6
# 4                        -

# %%
Oct_Dec2015_Final.replace('-',np.NaN,inplace = True)
Oct_Dec2015_Final.replace('(Z)',np.NaN,inplace = True)

Oct_Dec2015_Final.fillna(0,inplace = True)

Oct_Dec2015_Final
# Out:
#               State  Fall_2015\nNo_of_colonies  Fall_2015\nLost  \
# 0           Alabama                       8000              610
# 1           Arizona                      36000            12000
# 2          Arkansas                      23000             2400
# 3        California                     750000           149000
# 4          Colorado                      24000             2500
# 5       Connecticut                       3200              210
# 6           Florida                     220000            37000
# 7           Georgia                     110000            18000
# 8            Hawaii                      13000              690
# 9             Idaho                     121000            22000
# 10         Illinois                      14000              690
# 11          Indiana                      11500             1100
# 12             Iowa                      35000             4300
# 13           Kansas                       8500             3400
# ...

# %%
# Select the columns you want
#df1 = df[['a','d']]
#Jan_March2015_Columns = Jan_March2015_Final[["State", "Fall_2015\nNo_of_colonies", "Fall_2015\nLost",
                                              #"Fall_2015\nPer_lost", "Fall_2015\nAdded", "Fall_2015\nRenovated",
                                              #"Fall_2015\nPer_renovated"]]

# %%
#Merge winter and spring dataframes
#Jan_Mar2015_Final & Apr_Jun2015_Final
#Jan_Mar_Apr_Jun_Merged = pd.merge(Jan_Mar2015_Final, Apr_Jun2015_Final, how="left", on=["State","State"])

# %%
#Merge winter_spring with summer
#Jan_Mar__Apr_Jun_Merged $ Jul_Sep2015_Final
#Jan_to_Sep2015_Merged = pd.merge(Jan_Mar_Apr_Jun_Merged, Jul_Sep2015_Final, how="left, on=["State", "State"])

# %%
Final_Colony_2015 = Jan_Mar2015_Final.merge(Apr_Jun2015_Final, on="State").merge(Jul_Sep2015_Final, on="State").merge(Oct_Dec2015_Final, on="State")
Final_Colony_2015
# Out:
#               State  Winter_2015\nNo_of_colonies  Winter_2015\nLost  \
# 0           Alabama                         7000               1800
# 1           Arizona                        35000               4600
# 2          Arkansas                        13000               1500
# 3        California                      1440000             255000
# 4          Colorado                         3500               1500
# 5       Connecticut                         3900                870
# 6           Florida                       305000              42000
# 7           Georgia                       104000              14500
# 8            Hawaii                        10500                380
# 9             Idaho                        81000               3700
# 10         Illinois                         6000               4200
# 11          Indiana                         9000               2100
# 12             Iowa                        12500               3100
# ...

# %%
#Export Final_Colony_2015 to csv
Final_Colony_2015.to_csv("Final_Colony_2015.csv")
