# %%
import pandas as pd
import numpy as np

# %%
colony_2015_to_load = "Final_Colony_2015.csv"

# Read data File and store into Pandas Data Frames
colony_df_2015= pd.read_csv(colony_2015_to_load)
colony_df_2015.head()
# Out:
#    Unnamed: 0       State  Winter_2015\r\nNo_of_colonies  Winter_2015\r\nLost  \
# 0           0     Alabama                           7000                 1800
# 1           1     Arizona                          35000                 4600
# 2           2    Arkansas                          13000                 1500
# 3           3  California                        1440000               255000
# 4           4    Colorado                           3500                 1500
#
#    Winter_2015\r\nPer_lost  Winter_2015\r\nAdded  Winter_2015\r\nRenovated  \
# 0                       26                  2800                       250
# 1                       13                  3400                      2100
# 2                       11                  1200                        90
# 3                       15                250000                    124000
# 4                       12                   200                       140
#
# ...

# %%
list(colony_df_2015)
# Out:
# ['Unnamed: 0',
#  'State',
#  'Winter_2015\r\nNo_of_colonies',
#  'Winter_2015\r\nLost',
#  'Winter_2015\r\nPer_lost',
#  'Winter_2015\r\nAdded',
#  'Winter_2015\r\nRenovated',
#  'Winter_2015\r\nPer_renovated',
#  'Spring_2015\r\nNo_of_colonies',
#  'Spring_2015\r\nLost',
#  'Spring_2015\r\nPer_lost',
#  'Spring_2015\r\nAdded',
#  'Spring_2015\r\nRenovated',
#  'Spring_2015\r\nPer_renovated',
#  'Summer_2015\r\nNo_of_colonies',
#  'Summer_2015\r\nLost',
#  'Summer_2015\r\nPer_lost',
#  'Summer_2015\r\nAdded',
#  'Summer_2015\r\nRenovated',
#  'Summer_2015\r\nPer_renovated',
#  'Fall_2015\r\nNo_of_colonies',
#  'Fall_2015\r\nLost',
#  'Fall_2015\r\nPer_lost',
#  'Fall_2015\r\nAdded',
#  'Fall_2015\r\nRenovated',
#  'Fall_2015\r\nPer_renovated']

# %%
#Colony_losscolumns1_2015 = colony_df_2015.drop(colony_df_2015.columns[[0,2,4,5,6,7,8,10,11,12,13,14,]], axis=1) 
#
#Colony_losscolumns1_2015.head()

# %%
#Select "lost" columns from 2015 df
#df1 = df[['a','d']]
#Colony_losscolumns_2015 = colony_df_2015[['State', 'Winter_2015\r\nLost','Spring_2015\r\nLost',
#                                           'Summer_2015\r\nLost', 'Fall_2015\r\nLost']]
#Colony_losscolumns_2015.head()

# %%
#select "percent lost" columns from 2015 df
#df1 = df[['a','d']]

Colony_perlosscolumns_2015 = colony_df_2015[['State', 'Winter_2015\r\nPer_lost','Spring_2015\r\nPer_lost',
                                           'Summer_2015\r\nPer_lost', 'Fall_2015\r\nPer_lost']]
Colony_perlosscolumns_2015.head()
# Out:
#         State  Winter_2015\r\nPer_lost  Spring_2015\r\nPer_lost  \
# 0     Alabama                       26                       12
# 1     Arizona                       13                       17
# 2    Arkansas                       11                       14
# 3  California                       15                       10
# 4    Colorado                       12                        8
#
#    Summer_2015\r\nPer_lost  Fall_2015\r\nPer_lost
# 0                       16                      8
# 1                       15                     31
# 2                       30                      9
# 3                       10                     12
# 4                       15                     10

# %%
#####
##CAMILLA'S DATA
#####
colony_2016_to_load = "Final_Colony_2016.csv"

# Read data File and store into Pandas Data Frames
colony_df_2016= pd.read_csv(colony_2016_to_load)
colony_df_2016.head()
# Out:
#    Unnamed: 0       State  Winter_2016\nNo_of_colonies  Winter_2016\nLost  \
# 0           0     Alabama                         7500               1700
# 1           1     Arizona                        30000               4700
# 2           2    Arkansas                        27000               5000
# 3           3  California                      1130000             200000
# 4           4    Colorado                         5000                750
#
#    Winter_2016\nPer_lost  Winter_2016\nAdded  Winter_2016\nRenovated  \
# 0                     23                2100                      90
# 1                     16                3500                     150
# 2                     19                5000                    1100
# 3                     14              210000                  139000
# 4                      9                1700                      10
#
#    Winter_2016\nPer_renovated  Spring_2016\nNo_of_colonies  Spring_2016\nlost  \
# ...

# %%
list(colony_df_2016)
# Out:
# ['Unnamed: 0',
#  'State',
#  'Winter_2016\nNo_of_colonies',
#  'Winter_2016\nLost',
#  'Winter_2016\nPer_lost',
#  'Winter_2016\nAdded',
#  'Winter_2016\nRenovated',
#  'Winter_2016\nPer_renovated',
#  'Spring_2016\nNo_of_colonies',
#  'Spring_2016\nlost',
#  'Spring_2016\nPer_lost',
#  'Spring_2016\nAdded',
#  'Spring_2016\nRenovated',
#  'Spring_2016\nPer_renovated',
#  'Summer_2016\nNo_of_colonies',
#  'Summer_2016\nLost',
#  'Summer_2016\nPer_lost',
#  'Summer_2016\nAdded',
#  'Summer_2016\nRenovated',
#  'Summer_2016\nPer_renovated',
#  'Fall_2016\nNo_of_colonies',
#  'Fall_2016\nLost',
#  'Fall_2016\nPer_lost',
#  'Fall_2016\nAdded',
#  'Fall_2016\nRenovated',
#  'Fall_2016\nPer_renovated']

# %%
#select "percent lost" columns from 2016 df
#df1 = df[['a','d']]

Colony_perlosscolumns_2016 = colony_df_2016[['State', 'Winter_2016\nPer_lost','Spring_2016\nPer_lost',
                                           'Summer_2016\nPer_lost', 'Fall_2016\nPer_lost']]
Colony_perlosscolumns_2016.head()
# Out:
#         State  Winter_2016\nPer_lost Spring_2016\nPer_lost  \
# 0     Alabama                     23                    12
# 1     Arizona                     16                    16
# 2    Arkansas                     19                    14
# 3  California                     14                     9
# 4    Colorado                      9                     6
#
#    Summer_2016\nPer_lost  Fall_2016\nPer_lost
# 0                     15                    9
# 1                     19                   21
# 2                      5                    9
# 3                     10                   15
# 4                     18                   15

# %%
colony_2017_to_load = "Final_Colony_2017.csv"

# Read data File and store into Pandas Data Frames
colony_df_2017= pd.read_csv(colony_2017_to_load)
colony_df_2017.head()
# Out:
#         State  Winter_2017\nNo_of_colonies  Winter_2017\nLost  \
# 0     Alabama                         7000               1600
# 1     Arizona                        31000               6000
# 2    Arkansas                        18000               3500
# 3  California                      1170000             195000
# 4    Colorado                         9500               1100
#
#    Winter_2017\nPer_lost  Winter_2017\nAdded  Winter_2017\nRenovated  \
# 0                     23                 570                     740
# 1                     19                2900                       0
# 2                     18                 430                     230
# 3                     13              137000                   93000
# 4                      5                 100                       0
#
#    Winter_2017\nPer_renovated  Spring_2017\nNo_of_colonies  Spring_2017\nLost  \
# 0                          11                         6500                440
# ...

# %%
list(colony_df_2017)
# Out:
# ['State',
#  'Winter_2017\nNo_of_colonies',
#  'Winter_2017\nLost',
#  'Winter_2017\nPer_lost',
#  'Winter_2017\nAdded',
#  'Winter_2017\nRenovated',
#  'Winter_2017\nPer_renovated',
#  'Spring_2017\nNo_of_colonies',
#  'Spring_2017\nLost',
#  'Spring_2017\nPer_lost',
#  'Spring_2017\nAdded',
#  'Spring_2017\nRenovated',
#  'Spring_2017\nPer_renovated',
#  'Summer_2017\nNo_of_colonies',
#  'Summer_2017\nLost',
#  'Summer_2017\nPer_lost',
#  'Summer_2017\nAdded',
#  'Summer_2017\nRenovated',
#  'Summer_2017\nPer_renovated',
#  'Fall_2017\nNo_of_colonies',
#  'Fall_2017\nLost',
#  'Fall_2017\nPer_lost',
#  'Fall_2017\nAdded',
#  'Fall_2017\nRenovated',
#  'Fall_2017\nPer_renovated']

# %%
#select "percent lost" columns from 2017 df
#df1 = df[['a','d']]

Colony_perlosscolumns_2017 = colony_df_2017[['State', 'Winter_2017\nPer_lost','Spring_2017\nPer_lost',
                                           'Summer_2017\nPer_lost', 'Fall_2017\nPer_lost']]
Colony_perlosscolumns_2017.head()
# Out:
#         State  Winter_2017\nPer_lost  Spring_2017\nPer_lost  \
# 0     Alabama                     23                      7
# 1     Arizona                     19                     12
# 2    Arkansas                     18                      8
# 3  California                     13                      9
# 4    Colorado                      5                     15
#
#    Summer_2017\nPer_lost  Fall_2017\nPer_lost
# 0                      9                   13
# 1                     16                   22
# 2                     21                   30
# 3                     10                   13
# 4                     10                   21

# %%
colony_2018_to_load = "Final_Colony_2018.csv"

# Read data File and store into Pandas Data Frames
colony_df_2018= pd.read_csv(colony_2018_to_load)
colony_df_2018.head()
# Out:
#         State  Winter_2018\nNo_of_colonies  Winter_2018\nLost  \
# 0     Alabama                         7500                820
# 1     Arizona                        25000               6000
# 2    Arkansas                        22000               7500
# 3  California                      1150000             220000
# 4    Colorado                        13000               4900
#
#    Winter_2018\nPer_lost  Winter_2018\nAdded  Winter_2018\nRenovated  \
# 0                     11                1200                    1500
# 1                     23                 810                     230
# 2                     34                 540                     810
# 3                     14              200000                  132500
# 4                     23                1400                     190
#
#    Winter_2018\nPer_renovated  Spring_2018\nNo_of_colonies  Spring_2018\nLost  \
# 0                          20                         7500                810
# ...

# %%
list(colony_df_2018)
# Out:
# ['State',
#  'Winter_2018\nNo_of_colonies',
#  'Winter_2018\nLost',
#  'Winter_2018\nPer_lost',
#  'Winter_2018\nAdded',
#  'Winter_2018\nRenovated',
#  'Winter_2018\nPer_renovated',
#  'Spring_2018\nNo_of_colonies',
#  'Spring_2018\nLost',
#  'Spring_2018\nPer_lost',
#  'Spring_2018\nAdded',
#  'Spring_2018\nRenovated',
#  'Spring_2018\nPer_renovated']

# %%
#select "percent lost" columns from 2018 df
#df1 = df[['a','d']]

Colony_perlosscolumns_2018 = colony_df_2018[['State', 'Winter_2018\nPer_lost','Spring_2018\nPer_lost']]
Colony_perlosscolumns_2018.head()
# Out:
#         State  Winter_2018\nPer_lost  Spring_2018\nPer_lost
# 0     Alabama                     11                     10
# 1     Arizona                     23                     13
# 2    Arkansas                     34                     13
# 3  California                     14                      6
# 4    Colorado                     23                      9

# %%
Final_Colony_Percent_Lost = Colony_perlosscolumns_2015.merge(Colony_perlosscolumns_2016, on="State").merge(Colony_perlosscolumns_2017, on="State").merge(Colony_perlosscolumns_2018, on="State")
Final_Colony_Percent_Lost.head()
# Out:
#              State  Winter_2015\r\nPer_lost  Spring_2015\r\nPer_lost  \
# 0          Alabama                       26                       12
# 1          Arizona                       13                       17
# 2         Arkansas                       11                       14
# 3       California                       15                       10
# 4         Colorado                       12                        8
# 5      Connecticut                       22                        3
# 6          Florida                       13                       16
# 7          Georgia                       14                       19
# 8           Hawaii                        4                        1
# 9            Idaho                        4                        9
# 10        Illinois                       40                       14
# 11         Indiana                       22                       10
# 12            Iowa                       18                        6
# ...

# %%
#Export Final_Colony_Losses to csv
Final_Colony_Percent_Lost.to_csv("Final_Colony_Losses.csv")
